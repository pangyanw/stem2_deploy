# %% [markdown]
# Alice needs to match up buyers and sellers of a particular stock to facilitate transactions on her exchange.
# Her exchange recieves buy orders in the form of an integer:

# %%
buyAmount = 10

# %% [markdown]
# Her exchange also has on hand an array of sell order quantities which represent sell orders:

# %%
sellOrders = [5, 5, 1, 2, 2, 3]

# %% [markdown]
# Can you implement the following function which returns true if the buy order is fullfilable with the sell orders currently on book?

# %%
def isFullfilable(buyAmount, sellOrders):
    return False

# %% [markdown]
# For example: The above buyAmount of 10 can be placed by the first two sell orders 5 + 5 so this function should return true.
#
# buyAmount = 10
#
# sellOrders = [5, 5, 1, 2, 2, 3]
#
# isFullfilable(10, [5, 5, 1, 2, 2, 3]) == True

# %% [markdown]
# For the next example, the buyAmount cannot be placed as we cannot split sell orders, so the function should return false.
#
# buyAmount = 9
# sellOrders = [5, 5, 3]
#
# isFullfilable(10, [5, 5, 3]) == False

# %%
import unittest

class TestFullfilable(unittest.TestCase):
    def test_example_case(self):
        test_buy=10
        test_sells=[5, 5, 1, 2, 2, 3]
        expected=True
        self.assertEqual(isFullfilable(test_buy, test_sells), expected)
    def test_single_entry(self):
        test_buy=5
        test_sells=[5]
        expected=True
        self.assertEqual(isFullfilable(test_buy, test_sells), expected)
    def test_too_low(self):
        test_buy=15
        test_sells=[5,4,3,2,1]
        expected=False
        self.assertEqual(isFullfilable(test_buy, test_sells), expected)
    def test_identical_values(self):
        test_buy=9
        test_sells=[3,3,3,4,7,7]
        expected=True
        self.assertEqual(isFullfilable(test_buy, test_sells), expected)
    def test_no_sells(self):
        test_buy=1
        test_sells=[]
        expected=False
        self.assertEqual(isFullfilable(test_buy, test_sells), expected)
unittest.main(argv=[''], verbosity=0, exit=False)
